# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
sns.set_theme()
sales = pd.read_csv('top100videogamesales.csv')

# %%
sales.head(5)
# Out:
#    Rank                   Name  Platform  Year     Genre Publisher  NA_Sales  \
# 0     1             Wii Sports  Nintendo  2006    Sports  Nintendo     41.49
# 1     2         Mario Kart Wii  Nintendo  2008    Racing  Nintendo     15.85
# 2     3      Wii Sports Resort  Nintendo  2009    Sports  Nintendo     15.75
# 3     4  New Super Mario Bros.  Nintendo  2006  Platform  Nintendo     11.38
# 4     5               Wii Play  Nintendo  2006      Misc  Nintendo     14.03
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     29.02      3.77         8.46         82.74
# 1     12.88      3.79         3.31         35.82
# 2     11.01      3.28         2.96         33.00
# 3      9.23      6.50         2.90         30.01
# 4      9.20      2.93         2.85         29.02

# %% [markdown]
# 1)Regional Sales by Publisher: Create a stacked column (or bar) chart to show the sales by region for each publisher in the data. Explain your chart with markdown and detail which publisher had the most sales

# %%
s1 = sns.barplot(x = 'Publisher', y = 'NA_Sales', data = sales, color = 'red')

s2 = sns.barplot(x = 'Publisher', y = 'EU_Sales', data = sales, color = 'blue')

s3 = sns.barplot(x = 'Publisher', y = 'JP_Sales', data = sales, color = 'green')

s4 = sns.barplot(x = 'Publisher', y = 'Other_Sales', data = sales, color = 'orange')

#Figure out why this makes everything weird
#s5 = sns.barplot(x = 'Publisher', y = 'Global_Sales', data = sales, color = 'purple')

s1 = s1.set_xticklabels(s1.get_xticklabels(), rotation=40, ha="right")

#sns.set(rc = {'figure.figsize':(16,8)})
